# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Reading-DataFrames-from-pickle" data-toc-modified-id="Reading-DataFrames-from-pickle-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Reading DataFrames from pickle</a></span></li><li><span><a href="#Featuring" data-toc-modified-id="Featuring-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Featuring</a></span><ul class="toc-item"><li><span><a href="#Tratamiento-de-fechas" data-toc-modified-id="Tratamiento-de-fechas-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Tratamiento de fechas</a></span></li><li><span><a href="#Train-Test-split" data-toc-modified-id="Train-Test-split-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Train-Test split</a></span></li><li><span><a href="#Scaler" data-toc-modified-id="Scaler-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Scaler</a></span></li></ul></li><li><span><a href="#Models-for-percentaje-renovable-generation" data-toc-modified-id="Models-for-percentaje-renovable-generation-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Models for percentaje renovable generation</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Linear Regression</a></span></li><li><span><a href="#K-Neighbors" data-toc-modified-id="K-Neighbors-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>K-Neighbors</a></span></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Decision Tree</a></span></li><li><span><a href="#Boosting-Models" data-toc-modified-id="Boosting-Models-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Boosting Models</a></span><ul class="toc-item"><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>XGBoost</a></span></li><li><span><a href="#LightGBM" data-toc-modified-id="LightGBM-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>LightGBM</a></span></li></ul></li></ul></li><li><span><a href="#Evaluation-for-percentaje-renovable-generation" data-toc-modified-id="Evaluation-for-percentaje-renovable-generation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Evaluation for percentaje renovable generation</a></span><ul class="toc-item"><li><span><a href="#Model-choice" data-toc-modified-id="Model-choice-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Model choice</a></span></li></ul></li><li><span><a href="#Pipeline" data-toc-modified-id="Pipeline-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Pipeline</a></span></li></ul></div>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.multioutput import MultiOutputRegressor
from utils import date_transform,evaluation_function,plot_metrics,plot_real_vs_pred,train_test_val_split
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

pd.options.display.max_columns=None
warnings.filterwarnings("ignore")
plt.style.use('ggplot')
sns.set_palette("Set2")
sns.set_style("ticks")

path_Data='../Data/'

# %% [markdown]
# # Reading DataFrames from pickle

# %%
df_ree_weather=pd.read_pickle(path_Data+"Wheater_ree.pkl")

# %%
df_ree_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7480 entries, 0 to 7479
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   fecha                      7480 non-null   object
#  1   system                     7480 non-null   object
#  2   Holiday                    7480 non-null   int32
#  3   weekday                    7480 non-null   int32
#  4   tmin                       7480 non-null   float64
#  5   presMin                    7480 non-null   float64
#  6   prec                       7480 non-null   float64
#  7   tmed                       7480 non-null   float64
#  8   sol                        7480 non-null   float64
#  9   velmedia                   7480 non-null   float64
#  10  tmax                       7480 non-null   float64
#  11  presMax                    7480 non-null   float64
#  12  racha                      7480 non-null   float64
# ...

# %%
df_ree_weather.head(8)
# Out:
#         fecha      system  Holiday  weekday       tmin      presMin      prec  \
# 0  2016-01-01    baleares        1        4   3.300000  1009.300000  0.022222
# 1  2016-01-01    canarias        1        4   7.900000   894.700000  0.000000
# 2  2016-01-01     melilla        1        4  10.600000  1016.600000  0.000000
# 3  2016-01-01  peninsular        1        4   3.817021   921.165957  5.477102
# 4  2016-01-02    baleares        0        5   3.900000  1006.400000  0.000000
# 5  2016-01-02    canarias        0        5   8.000000   895.150000  0.000000
# 6  2016-01-02     melilla        0        5  11.600000  1016.400000  0.000000
# 7  2016-01-02  peninsular        0        5   2.136170   922.636170  0.791592
#
#         tmed       sol  velmedia       tmax      presMax      racha  year  \
# 0  13.022222  1.940000  2.366667  18.900000  1024.900000  14.200000  2016
# 1  18.040000  9.266667  2.781667  24.250000  1025.450000  10.400000  2016
# ...

# %% [markdown]
# # Featuring

# %%
from sklearn.preprocessing import OneHotEncoder

enc_system=OneHotEncoder().fit(df_ree_weather[['system']])

df_transform_weather=enc_system.transform(df_ree_weather[['system']])

column_weather=enc_system.get_feature_names()

df_onehot_weather = pd.DataFrame(df_transform_weather.todense(),columns=column_weather)

     
df_weather_features=pd.merge(df_ree_weather,df_onehot_weather,left_index=True,right_index=True)                               
df_weather_features.drop('system',axis=1,inplace=True)

# %%
df_weather_features.head()
# Out:
#         fecha  Holiday  weekday       tmin      presMin      prec       tmed  \
# 0  2016-01-01        1        4   3.300000  1009.300000  0.022222  13.022222
# 1  2016-01-01        1        4   7.900000   894.700000  0.000000  18.040000
# 2  2016-01-01        1        4  10.600000  1016.600000  0.000000  15.500000
# 3  2016-01-01        1        4   3.817021   921.165957  5.477102  10.207533
# 4  2016-01-02        0        5   3.900000  1006.400000  0.000000  13.588889
#
#         sol  velmedia       tmax      presMax      racha  year  month  day  \
# 0  1.940000  2.366667  18.900000  1024.900000  14.200000  2016      1    1
# 1  9.266667  2.781667  24.250000  1025.450000  10.400000  2016      1    1
# 2  9.100000  1.700000  20.400000  1019.900000   5.600000  2016      1    1
# 3  2.231907  3.189763  16.440426   984.380851  16.361702  2016      1    1
# 4  3.140000  4.488889  20.700000  1021.200000  23.300000  2016      1    2
#
# ...

# %%
df_weather_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7480 entries, 0 to 7479
# Data columns (total 39 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   fecha                      7480 non-null   object
#  1   Holiday                    7480 non-null   int32
#  2   weekday                    7480 non-null   int32
#  3   tmin                       7480 non-null   float64
#  4   presMin                    7480 non-null   float64
#  5   prec                       7480 non-null   float64
#  6   tmed                       7480 non-null   float64
#  7   sol                        7480 non-null   float64
#  8   velmedia                   7480 non-null   float64
#  9   tmax                       7480 non-null   float64
#  10  presMax                    7480 non-null   float64
#  11  racha                      7480 non-null   float64
#  12  year                       7480 non-null   int32
# ...

# %% [markdown]
# ##  Tratamiento de fechas
#
# Para pasar las fechas aun formato en que el salto entre el ultimo dia de un mes y el primer dia del siguiente sea continuo, uso los cosenos de los dias y meses.
#
# Para ello situo los valores de los 31 dias en angulos iguales calulandolos como $Dia(x)=\cos\frac{2\pi}{31}x$
#
# Para los meses situo cada mes en $Mes(x)=\cos\frac{2\pi}{12}x$
#
# Y para los dias de la semana $Weekday(x)=\cos\frac{2\pi}{7}x$

# %%
df_weather_procesed=date_transform(df_weather_features);
df_weather_procesed.head(8)
# Out:
#         fecha  Holiday   weekday       tmin      presMin      prec       tmed  \
# 0  2016-01-01        1 -0.900969   3.300000  1009.300000  0.022222  13.022222
# 1  2016-01-01        1 -0.900969   7.900000   894.700000  0.000000  18.040000
# 2  2016-01-01        1 -0.900969  10.600000  1016.600000  0.000000  15.500000
# 3  2016-01-01        1 -0.900969   3.817021   921.165957  5.477102  10.207533
# 4  2016-01-02        0 -0.222521   3.900000  1006.400000  0.000000  13.588889
# 5  2016-01-02        0 -0.222521   8.000000   895.150000  0.000000  18.325000
# 6  2016-01-02        0 -0.222521  11.600000  1016.400000  0.000000  17.000000
# 7  2016-01-02        0 -0.222521   2.136170   922.636170  0.791592   8.648970
#
#         sol  velmedia       tmax      presMax      racha      year     month  \
# 0  1.940000  2.366667  18.900000  1024.900000  14.200000  7.608871  0.866025
# 1  9.266667  2.781667  24.250000  1025.450000  10.400000  7.608871  0.866025
# ...

# %%
features_list=['Holiday','weekday','tmin','presMin','prec','sol','tmax','presMax','racha','velmedia','year','day','month','x0_baleares','x0_canarias','x0_melilla','x0_peninsular']
target_list=['x0_Solar fotovoltaica','x0_Eólica','x0_baleares','x0_canarias','x0_melilla','x0_peninsular']

# %% [markdown]
# ## Train-Test split

# %%
X_train,X_test,y_train,y_test,X_validation,y_validacion=train_test_val_split(df_weather_procesed,
                                                                        features_list,
                                                                        target_list,
                                                                        .1,
                                                                        0)

# %% [markdown]
# ## Scaler

# %%
from sklearn.preprocessing import StandardScaler

cols_scaler=['tmin','presMin','prec','sol','tmax','presMax','racha','velmedia']
scaler=StandardScaler().fit(X_train[cols_scaler])

X_train[cols_scaler]=scaler.transform(X_train[cols_scaler])
X_test[cols_scaler]=scaler.transform(X_test[cols_scaler])
X_train.head()
# Out:
#    Holiday   weekday      tmin   presMin      prec       sol      tmax  \
# 0        1 -0.900969 -1.136261  1.001632 -0.299348 -1.860133 -0.912298
# 1        1 -0.900969 -0.427684 -1.208123 -0.305329  0.460875 -0.026751
# 2        1 -0.900969 -0.011780  1.142394 -0.305329  0.408077 -0.664014
# 3        1 -0.900969 -1.056619 -0.697798  1.168923 -1.767660 -1.319413
# 4        0 -0.222521 -1.043838  0.945714 -0.305329 -1.479986 -0.614357
#
#     presMax     racha  velmedia      year       day     month  x0_baleares  \
# 0  0.989529  0.086529 -0.813986  7.608871  0.979530  0.866025          1.0
# 1  1.022056 -0.660018 -0.508034  7.608871  0.979530  0.866025          0.0
# 2  0.693821 -1.603026 -1.305476  7.608871  0.979530  0.866025          0.0
# 3 -1.406834  0.511217 -0.207171  7.608871  0.979530  0.866025          0.0
# 4  0.770705  1.874314  0.750589  7.608871  0.918958  0.866025          1.0
#
#    x0_canarias  x0_melilla  x0_peninsular
# 0          0.0         0.0            0.0
# ...

# %%
y_train
# Out:
#       x0_Solar fotovoltaica  x0_Eólica  x0_baleares  x0_canarias  x0_melilla  \
# 0                  0.016359   0.001254          1.0          0.0         0.0
# 1                  0.034486   0.018968          0.0          1.0         0.0
# 2                  0.000303   0.000000          0.0          0.0         1.0
# 3                  0.015230   0.371330          0.0          0.0         0.0
# 4                  0.020613   0.002847          1.0          0.0         0.0
# ...                     ...        ...          ...          ...         ...
# 6727               0.066321   0.199540          0.0          0.0         0.0
# 6728               0.032122   0.002913          1.0          0.0         0.0
# 6729               0.029387   0.084714          0.0          1.0         0.0
# 6730               0.000377   0.000000          0.0          0.0         1.0
# 6731               0.068985   0.102862          0.0          0.0         0.0
#
#       x0_peninsular
# 0               0.0
# ...

# %% [markdown]
# # Models for percentaje renovable generation

# %%
scoring_metrics=['neg_root_mean_squared_error','r2','neg_mean_absolute_error']

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression


reg_ln=MultiOutputRegressor(LinearRegression())

reg_ln.fit(X_train,y_train[['x0_Solar fotovoltaica','x0_Eólica']])

y_pred_ln=reg_ln.predict(X_test)

# %% [markdown]
# ## K-Neighbors

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV

reg_KN=GridSearchCV(MultiOutputRegressor(KNeighborsRegressor()),
                    param_grid={"estimator__n_neighbors":np.arange(3,80)},
                    refit='neg_root_mean_squared_error',
                    scoring=scoring_metrics)

reg_KN.fit(X_train,y_train[['x0_Solar fotovoltaica','x0_Eólica']])

y_pred_KN=reg_KN.predict(X_test)
reg_KN.best_estimator_
# Out:
# MultiOutputRegressor(estimator=KNeighborsRegressor(n_neighbors=14))

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

params_DT={
           'estimator__max_depth':range(3,10),
           'estimator__min_samples_leaf':range(1,3)
            }

reg_DT=GridSearchCV(MultiOutputRegressor(DecisionTreeRegressor(random_state=7)),
                    param_grid=params_DT,
                    refit='neg_root_mean_squared_error',
                    scoring=scoring_metrics)

reg_DT.fit(X_train,y_train[['x0_Solar fotovoltaica','x0_Eólica']])
y_pred_DT=reg_DT.predict(X_test)
reg_DT.best_params_
# Out:
# {'estimator__max_depth': 8, 'estimator__min_samples_leaf': 2}

# %% [markdown]
# ## Boosting Models

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBRegressor

params_xgb={
    'estimator__max_depth':range(4,6),
    'estimator__n_estimators':range(40,60,1),
    'estimator__learning_rate':np.arange(.08,.12,.01),
    'estimator__subsample':np.arange(.5,.9,0.1),
    'estimator__colsample_bytree':np.arange(.5,1,0.1)
    }

reg_XGB=GridSearchCV(MultiOutputRegressor(XGBRegressor(objective='reg:squarederror',random_state=7)),
                     param_grid=params_xgb,
                     refit='neg_root_mean_squared_error',
                     scoring=scoring_metrics)

reg_XGB.fit(X_train,y_train[['x0_Solar fotovoltaica','x0_Eólica']])
y_pred_XGB=reg_XGB.predict(X_test)

print(reg_XGB.best_params_)
print(reg_XGB.best_estimator_)
print(reg_XGB.best_score_)
# Out:
# {'estimator__colsample_bytree': 0.8999999999999999, 'estimator__learning_rate': 0.09999999999999999, 'estimator__max_depth': 5, 'estimator__n_estimators': 59, 'estimator__subsample': 0.7}
# MultiOutputRegressor(estimator=XGBRegressor(base_score=None, booster=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8999999999999999,
#                                             gamma=None, gpu_id=None,
#                                             importance_type='gain',
#                                             interaction_constraints=None,
#                                             learning_rate=0.09999999999999999,
#                                             max_delta_step=None, max_depth=5,
#                                             min_child_weight=None, missing=nan,
# ...

# %% [markdown]
# ### LightGBM

# %%
from lightgbm import LGBMRegressor

params_LGBM={
    'estimator__max_depth':range(4,6),
    'estimator__n_estimators':range(90,110,1),
    'estimator__learning_rate':np.arange(.07,.11,.1),
    'estimator__subsample':np.arange(.5,0.7,0.1),
    'estimator__colsample_bytree':np.arange(.5,1,0.1)
    }

reg_LGBM=GridSearchCV(MultiOutputRegressor(LGBMRegressor(random_state=7)),
                      param_grid=params_LGBM,
                      refit='neg_root_mean_squared_error',
                      scoring=scoring_metrics)

reg_LGBM.fit(X_train,y_train[['x0_Solar fotovoltaica','x0_Eólica']])
y_pred_LGBM=reg_LGBM.predict(X_test)

print(reg_LGBM.best_params_)
print(reg_LGBM.best_estimator_)
print(reg_LGBM.best_score_)
# Out:
# {'estimator__colsample_bytree': 0.7999999999999999, 'estimator__learning_rate': 0.07, 'estimator__max_depth': 5, 'estimator__n_estimators': 105, 'estimator__subsample': 0.5}
# MultiOutputRegressor(estimator=LGBMRegressor(colsample_bytree=0.7999999999999999,
#                                              learning_rate=0.07, max_depth=5,
#                                              n_estimators=105, random_state=7,
#                                              subsample=0.5))
# -0.01689795098180586

# %% [markdown]
# # Evaluation for percentaje renovable generation

# %% [markdown]
# ## Model choice

# %%
pd_ln=evaluation_function(y_test[['x0_Solar fotovoltaica','x0_Eólica']],y_pred_ln,'LinearRegresion (Base Model)')
pd_kn=evaluation_function(y_test[['x0_Solar fotovoltaica','x0_Eólica']],y_pred_KN,'KNeighbors')
pd_DT=evaluation_function(y_test[['x0_Solar fotovoltaica','x0_Eólica']],y_pred_DT,'DecissionTree')
pd_XGB=evaluation_function(y_test[['x0_Solar fotovoltaica','x0_Eólica']],y_pred_XGB,'XGBoost')
pd_LGBM=evaluation_function(y_test[['x0_Solar fotovoltaica','x0_Eólica']],y_pred_LGBM,'LightGBM')

plot_metrics([pd_ln,pd_kn,pd_DT,pd_XGB,pd_LGBM])

# %%
plot_real_vs_pred('x0_peninsular',['x0_Solar fotovoltaica','x0_Eólica'],
                   X_test,y_test, reg_ln, reg_KN, reg_DT, reg_XGB, reg_LGBM)

# %%
plot_real_vs_pred('x0_baleares',['x0_Solar fotovoltaica','x0_Eólica'],
                   X_test,y_test, reg_ln, reg_KN, reg_DT, reg_XGB, reg_LGBM)

# %% [markdown]
# # Pipeline

# %%
import joblib
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer

cols=['day','year','month','system','Holiday','weekday','tmin','presMin','prec','sol','velmedia','tmax','presMax','racha']

ct=ColumnTransformer(
    [
     ('enc',enc_system,['system']),
     ('date_transf',FunctionTransformer(date_transform),['day','year','month','weekday']),
     ('sc',StandardScaler(),cols_scaler)
    ]
)

pipe_best_tech=Pipeline(steps=[
                                ('ct',ct),
                                ('LGBM',MultiOutputRegressor(LGBMRegressor(random_state=7)))
                               ])


params_LGBM={
    'LGBM__estimator__max_depth':[5],
    'LGBM__estimator__n_estimators':[105],
    'LGBM__estimator__learning_rate':[.07],
    'LGBM__estimator__subsample':[.5],
    'LGBM__estimator__colsample_bytree':[.8]
    }


reg_LGBM=GridSearchCV(pipe_best_tech,param_grid=params_LGBM,
                      refit='neg_root_mean_squared_error',
                      scoring=scoring_metrics)

reg_LGBM.fit(df_ree_weather[cols],df_ree_weather[['x0_Solar fotovoltaica','x0_Eólica']])

path_model='../models/'

joblib.dump(reg_LGBM,path_model+ 'best_model_tech.sav')
# Out:
# -0.019111814732782402
# ['../models/best_model_tech.sav']
